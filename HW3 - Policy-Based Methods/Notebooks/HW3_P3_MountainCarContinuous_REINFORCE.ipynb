# %% [markdown]
# # Run this Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DeepRLCourse/Homework-3-Questions/blob/main/HW3_P3_MountainCarContinuous_REINFORCE.ipynb)
# [![Open in Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/DeepRLCourse/Homework-3-Questions/blob/main/HW3_P3_MountainCarContinuous_REINFORCE.ipynb)
#
# # HW3: REINFORCE with continous action space in MountainCarContinous
# > - Full Name: **Ashkan Majidi**
# > - Student ID: **400109984**
#
#
# This notebook implements the **REINFORCE policy gradient algorithm** to train an agent in the **MountainCarContinuous-v0** environment. The objective is to evaluate the performance and stability of REINFORCE in a continuous action space.
#
# Follow the instructions in each section to complete the homework.
#
# **Grading Breakdown:**
#
# - Practical Implementation: 80 points
# - Conceptual Understanding: 20 points

# %% [markdown]
# # Setup

# %% [markdown]
# All required packages are pre-installed if using Google Colab.

# %% [markdown]
# Import the following libraries.

# %%
# Required Libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import gym
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import base64
import imageio
import IPython
import logging
import warnings

# Disable warnings
logging.getLogger().setLevel(logging.ERROR)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# DEVICE
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# Configure Matplotlib for Interactive and XKCD-Style Plots

# %%
# Set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()
plt.xkcd(scale=1, length=100, randomness=2)
matplotlib.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# Record and Embed Simulation Videos in Jupyter Notebook

# %% [markdown]
# <b>embed_mp4:</b> Converts an MP4 video into a base64-encoded HTML tag for display in Jupyter Notebook.
# <br>
# <b>record_simulation:</b> Runs a policy in the environment, records the simulation, and saves it as an MP4 video.

# %%
def embed_mp4(filename):
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())
    return IPython.display.HTML(tag)

def record_simulation(env, policy_net, filename, episodes=1, fps=30):
    filename = filename + ".mp4"
    with imageio.get_writer(filename, fps=fps) as video:
        for _ in range(episodes):
            state = env.reset()
            frame = env.render()  # Capture the first frame
            video.append_data(frame[0])

            done = False
            while not done:
                state_tensor = torch.FloatTensor(state).to(DEVICE)
                mean, _ = policy_net(state_tensor)
                action = mean.item()
                state, _, terminated, truncated, _ = env.step([action])

                frame = env.render()  # Capture the frame after taking the action
                video.append_data(frame[0])

                done = terminated or truncated
    return embed_mp4(filename)

# %% [markdown]
# # Explore the environment (10 points)

# %% [markdown]
# Initialize MountainCarContinuous Environment and Display State & Action Spaces

# %%
# Create the MountainCarContinuous environment
env = gym.make("MountainCarContinuous-v0")

# Print observation and action space
print("Observation Space:", env.observation_space)
print("Action Space:", env.action_space)
# Out:
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Action Space: Box(-1.0, 1.0, (1,), float32)

# %% [markdown]
# **Question 1: (5 points)**
#
# How are the observation and action spaces defined in the MountainCarContinuous environment?
#
# .....</br>
# .....</br>
#
#
# `Check the Report`

# %% [markdown]
# Define a Random Policy for Action Selection

# %%
class RandomPolicy(object):

    def __init__(self, action_space_n):
        self.action_space_n = action_space_n

    def __call__(self, state):
        action_values, nan = torch.rand(self.action_space_n), np.nan
        return action_values, nan

# %% [markdown]
# Visualize the random policy.

# %%
random_policy = RandomPolicy(env.action_space.shape[0])

record_simulation(gym.make("MountainCarContinuous-v0", render_mode='rgb_array', new_step_api=True), random_policy, "Video_MountainCarContinuous_random_policy")
# Out:
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %% [markdown]
# **Question 2: (5 points)**
#
# How could an agent reach the goal in the MountainCarContinuous environment while using the least amount of energy? Explain a scenario describing the agent's behavior during an episode with most optimal policy.
#
# .....</br>
# .....</br>
#
# `Check the Report`

# %% [markdown]
# # Agent with REINFORCE in a continuous action space in MountainCarContinuous-v0 (80 points)

# %% [markdown]
# ### Policy Network Definition (10 points)

# %% [markdown]
# In continuous action spaces, instead of choosing from a discrete set of actions, the policy network learns a Gaussian distribution
# $\pi_\theta(a|s)$ over possible actions. The agent then samples an action from this distribution:
#
# $$a \sim \mathcal{N}(\mu_\theta(s), \sigma_\theta(s))$$
#
# where:
#
# - $\mu_\theta(s)$ is the mean of the action distribution.
# - $\sigma_\theta(s)$ is the standard deviation (exploration factor).
#
# The network is trained using policy gradients, reinforcing actions that lead to better rewards.

# %%
# TODO: Policy Network for Continuous Action Space
import torch.nn.functional as F

class PolicyNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.mean = nn.Linear(128, action_dim)
        # self.log_std = nn.Linear(128, action_dim)
        self.log_std = nn.Parameter(torch.zeros(action_dim), requires_grad=True)

    def forward(self, x):
        x1 = F.relu(self.fc1(x))
        x2 = F.relu(self.fc2(x1))
        x3 = x1 + x2
        mean = self.mean(x3)
        # log_std = self.log_std(x)
        log_std = self.log_std
        std = torch.exp(log_std)
        return mean, std

# %% [markdown]
# ### Computing Discounted Returns (15 points)

# %% [markdown]
# To implement a function that calculates the discounted return for each timestep in an episode.
#
# $$[
# G_t = \sum_{k=0}^{T-t} \gamma^k R_{t+k}
# ]$$

# %%
# REINFORCE Algorithm for Continuous Action Space
def compute_returns(rewards, gamma=0.99):
    # TODO: Your code here
    R = 0
    returns = []
    for r in reversed(rewards):
        R = r + gamma * R
        returns.insert(0, R)
    return returns

# %% [markdown]
# ### Implementing the REINFORCE Algorithm in continuous action space (45 points)

# %% [markdown]
# To train the agent using the standard policy gradient method.
# The REINFORCE algorithm updates policy parameters by using the log-probability of actions multiplied by the discounted return.
#
# This algorithm optimizes a **stochastic policy** $( \pi_{\theta}(a_t \mid s_t) )$ by updating its parameters in the direction that increases expected rewards. The update rule is based on the **policy gradient theorem**:
#
# $$[
# \theta \leftarrow \theta + \alpha \sum_{t=0}^{T} \nabla_{\theta} \log \pi_{\theta}(a_t \mid s_t) G_t
# ]$$
#
# where:
#
# - $( \theta )$ are the policy parameters (weights of the neural network).
# - $( \alpha )$ is the learning rate.
# - $( G_t )$ is the **discounted return** from timestep $( t )$:
#
# - $( \nabla_{\theta} \log \pi_{\theta}(a_t \mid s_t) )$ is the gradient of the log-probability of the selected action, used to adjust the policy in the correct direction.

# %%
import torch
import torch.nn.functional as F
from torch.distributions import Normal
from tqdm import tqdm

def reinforce(env, policy_net, optimizer, num_episodes=1000, gamma=0.99):
    rewards_per_episode = []

    for episode in range(num_episodes):
        state = env.reset()
        log_probs = []
        rewards = []

        done = False
        while not done:
            # state_tensor = torch.FloatTensor(state).unsqueeze(0).to(DEVICE)
            state_tensor = torch.tensor(state, dtype=torch.float32).to(DEVICE)
            mean, std = policy_net(state_tensor)
            dist = Normal(mean, std)
            action = dist.sample()
            log_prob = dist.log_prob(action)
            # print(log_prob)
            log_probs.append(log_prob)

            action = action.clamp(env.action_space.low[0], env.action_space.high[0])
            next_state, reward, done, _ = env.step(action.detach().cpu().numpy())
            rewards.append(reward)
            state = next_state

        rewards_per_episode.append(sum(rewards))

        # Compute discounted rewards
        discounted_rewards = compute_returns(rewards, gamma)

        discounted_rewards = torch.FloatTensor(discounted_rewards).to(DEVICE)
        # discounted_rewards = (discounted_rewards - discounted_rewards.mean()) / (discounted_rewards.std() + 1e-9)

        policy_loss = []
        for log_prob, reward in zip(log_probs, discounted_rewards):
            policy_loss.append(-log_prob * reward)
        policy_loss = torch.cat(policy_loss).sum()

        optimizer.zero_grad()
        policy_loss.backward()
        optimizer.step()

        if (episode + 1) % 50 == 0:
            for name, param in policy_net.named_parameters():
                if param.grad is not None:
                    print(f"{name} gradient norm: {param.grad.norm().item()}")
            print('-'*100)
            print(f"Episode {episode + 1}, Reward: {sum(rewards)}")
            print('-'*100)

    return rewards_per_episode

# %% [markdown]
# ### Training (10 points)

# %% [markdown]
# To define key hyperparameters that influence training efficiency and convergence.
#
# Hyperparameters like learning rate, discount factor, and number of episodes significantly impact the training process. Proper tuning is necessary to ensure stable learning while avoiding slow convergence or premature convergence to suboptimal policies.

# %%
# from torch.nn import DataParallel
# TODO: Define all necessary hyperparameters
INPUT_DIM = env.observation_space.shape[0]
OUTPUT_DIM = env.action_space.shape[0]
LEARNING_RATE = 4e-3
DISCOUNT_FACTOR = 0.98
NUM_EPISODES = 1500

# Initialize Policy
policy = PolicyNetwork(INPUT_DIM, OUTPUT_DIM).to(DEVICE)
# policy = DataParallel(PolicyNetwork(INPUT_DIM, OUTPUT_DIM)).to(DEVICE)

# Optimizer
optimizer= optim.Adam(policy.parameters(), lr=LEARNING_RATE)

# Training
print("Training REINFORCE Algorithm for Continuous Action Space:")
rewards = reinforce(env, policy, optimizer, num_episodes=NUM_EPISODES, gamma=DISCOUNT_FACTOR)
# Out:
# Training REINFORCE Algorithm for Continuous Action Space:
# log_std gradient norm: 98.58282470703125
# fc1.weight gradient norm: 29.419940948486328
# fc1.bias gradient norm: 65.29582214355469
# fc2.weight gradient norm: 102.73949432373047
# fc2.bias gradient norm: 30.812257766723633
# mean.weight gradient norm: 648.0442504882812
# mean.bias gradient norm: 159.69361877441406
# ----------------------------------------------------------------------------------------------------
# Episode 50, Reward: -57.54342489622345
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 160.64466857910156
# fc1.weight gradient norm: 28.103923797607422
# fc1.bias gradient norm: 78.41321563720703
# fc2.weight gradient norm: 86.42591094970703
# fc2.bias gradient norm: 27.927143096923828
# mean.weight gradient norm: 516.7492065429688
# mean.bias gradient norm: 120.49649047851562
# ----------------------------------------------------------------------------------------------------
# Episode 100, Reward: -75.34587430108402
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 38.713829040527344
# fc1.weight gradient norm: 10.06229305267334
# fc1.bias gradient norm: 60.342037200927734
# fc2.weight gradient norm: 59.877742767333984
# fc2.bias gradient norm: 20.245437622070312
# mean.weight gradient norm: 397.4245910644531
# mean.bias gradient norm: 96.95112609863281
# ----------------------------------------------------------------------------------------------------
# Episode 150, Reward: -66.89037975167574
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 369.7627258300781
# fc1.weight gradient norm: 51.05105209350586
# fc1.bias gradient norm: 138.0224609375
# fc2.weight gradient norm: 114.44829559326172
# fc2.bias gradient norm: 37.428428649902344
# mean.weight gradient norm: 533.1897583007812
# mean.bias gradient norm: 109.1430435180664
# ----------------------------------------------------------------------------------------------------
# Episode 200, Reward: -96.56048794318318
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 161.5819549560547
# fc1.weight gradient norm: 14.453201293945312
# fc1.bias gradient norm: 272.6054992675781
# fc2.weight gradient norm: 185.18467712402344
# fc2.bias gradient norm: 60.15621566772461
# mean.weight gradient norm: 995.7540893554688
# mean.bias gradient norm: 149.81903076171875
# ----------------------------------------------------------------------------------------------------
# Episode 250, Reward: -90.25033228278988
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 287.1308898925781
# fc1.weight gradient norm: 121.10741424560547
# fc1.bias gradient norm: 504.0194396972656
# fc2.weight gradient norm: 340.731201171875
# fc2.bias gradient norm: 113.48049926757812
# mean.weight gradient norm: 1675.709228515625
# mean.bias gradient norm: 225.75439453125
# ----------------------------------------------------------------------------------------------------
# Episode 300, Reward: -99.17697473136118
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 199.12908935546875
# fc1.weight gradient norm: 111.7567367553711
# fc1.bias gradient norm: 759.9175415039062
# fc2.weight gradient norm: 332.453857421875
# fc2.bias gradient norm: 99.70372772216797
# mean.weight gradient norm: 1952.8050537109375
# mean.bias gradient norm: 165.8867950439453
# ----------------------------------------------------------------------------------------------------
# Episode 350, Reward: -99.8999999999986
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 70.78255462646484
# fc1.weight gradient norm: 26.523210525512695
# fc1.bias gradient norm: 131.5561981201172
# fc2.weight gradient norm: 50.72351837158203
# fc2.bias gradient norm: 13.012786865234375
# mean.weight gradient norm: 332.47998046875
# mean.bias gradient norm: 22.52054214477539
# ----------------------------------------------------------------------------------------------------
# Episode 400, Reward: -99.33893165635756
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 52.01498794555664
# fc1.weight gradient norm: 333.4132080078125
# fc1.bias gradient norm: 1280.952392578125
# fc2.weight gradient norm: 566.4010620117188
# fc2.bias gradient norm: 177.01771545410156
# mean.weight gradient norm: 3083.989501953125
# mean.bias gradient norm: 229.0852508544922
# ----------------------------------------------------------------------------------------------------
# Episode 450, Reward: -99.8999999999986
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 477.5098876953125
# fc1.weight gradient norm: 492.4186706542969
# fc1.bias gradient norm: 1514.2523193359375
# fc2.weight gradient norm: 683.5018310546875
# fc2.bias gradient norm: 208.35887145996094
# mean.weight gradient norm: 3646.386962890625
# mean.bias gradient norm: 246.28121948242188
# ----------------------------------------------------------------------------------------------------
# Episode 500, Reward: -99.8999999999986
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 23.67320442199707
# fc1.weight gradient norm: 23.654338836669922
# fc1.bias gradient norm: 47.94226837158203
# fc2.weight gradient norm: 14.431142807006836
# fc2.bias gradient norm: 2.8235857486724854
# mean.weight gradient norm: 98.93867492675781
# mean.bias gradient norm: 4.285884857177734
# ----------------------------------------------------------------------------------------------------
# Episode 550, Reward: -99.8999999999986
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 174.64321899414062
# fc1.weight gradient norm: 178.19903564453125
# fc1.bias gradient norm: 146.24795532226562
# fc2.weight gradient norm: 95.84243774414062
# fc2.bias gradient norm: 6.446247577667236
# mean.weight gradient norm: 669.8289794921875
# mean.bias gradient norm: 8.70077896118164
# ----------------------------------------------------------------------------------------------------
# Episode 600, Reward: -99.54109169622154
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 108.69436645507812
# fc1.weight gradient norm: 55.89359664916992
# fc1.bias gradient norm: 193.8863983154297
# fc2.weight gradient norm: 127.21376037597656
# fc2.bias gradient norm: 39.6255989074707
# mean.weight gradient norm: 603.8781127929688
# mean.bias gradient norm: 27.592958450317383
# ----------------------------------------------------------------------------------------------------
# Episode 650, Reward: -70.83149486027322
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 126.29402160644531
# fc1.weight gradient norm: 47.40729904174805
# fc1.bias gradient norm: 124.34371948242188
# fc2.weight gradient norm: 84.56661987304688
# fc2.bias gradient norm: 23.83033561706543
# mean.weight gradient norm: 335.894287109375
# mean.bias gradient norm: 6.919634819030762
# ----------------------------------------------------------------------------------------------------
# Episode 700, Reward: -98.14329668705167
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 160.94178771972656
# fc1.weight gradient norm: 110.22551727294922
# fc1.bias gradient norm: 351.7244873046875
# fc2.weight gradient norm: 205.30914306640625
# fc2.bias gradient norm: 75.15815734863281
# mean.weight gradient norm: 1046.5372314453125
# mean.bias gradient norm: 161.88006591796875
# ----------------------------------------------------------------------------------------------------
# Episode 750, Reward: -99.8999999999986
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 344.2286682128906
# fc1.weight gradient norm: 119.07723999023438
# fc1.bias gradient norm: 300.6190490722656
# fc2.weight gradient norm: 173.89779663085938
# fc2.bias gradient norm: 67.78900146484375
# mean.weight gradient norm: 987.2012329101562
# mean.bias gradient norm: 209.24778747558594
# ----------------------------------------------------------------------------------------------------
# Episode 800, Reward: -97.31944287324193
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 46.53264236450195
# fc1.weight gradient norm: 81.80905151367188
# fc1.bias gradient norm: 229.14663696289062
# fc2.weight gradient norm: 128.95372009277344
# fc2.bias gradient norm: 50.53157043457031
# mean.weight gradient norm: 755.0079345703125
# mean.bias gradient norm: 177.11692810058594
# ----------------------------------------------------------------------------------------------------
# Episode 850, Reward: -90.62547037190804
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 112.73507690429688
# fc1.weight gradient norm: 260.8825378417969
# fc1.bias gradient norm: 684.8271484375
# fc2.weight gradient norm: 396.62872314453125
# fc2.bias gradient norm: 143.016357421875
# mean.weight gradient norm: 3166.554443359375
# mean.bias gradient norm: 802.46435546875
# ----------------------------------------------------------------------------------------------------
# Episode 900, Reward: 47.22225210740252
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 668.6982421875
# fc1.weight gradient norm: 137.58074951171875
# fc1.bias gradient norm: 264.2427978515625
# fc2.weight gradient norm: 314.70294189453125
# fc2.bias gradient norm: 83.8088150024414
# mean.weight gradient norm: 1461.1324462890625
# mean.bias gradient norm: 191.2838897705078
# ----------------------------------------------------------------------------------------------------
# Episode 950, Reward: 64.70523671582842
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 79.9311752319336
# fc1.weight gradient norm: 27.27471351623535
# fc1.bias gradient norm: 232.53927612304688
# fc2.weight gradient norm: 129.44403076171875
# fc2.bias gradient norm: 50.681819915771484
# mean.weight gradient norm: 608.4815063476562
# mean.bias gradient norm: 159.01280212402344
# ----------------------------------------------------------------------------------------------------
# Episode 1000, Reward: -97.25566125987365
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 234.96844482421875
# fc1.weight gradient norm: 296.1270446777344
# fc1.bias gradient norm: 1004.5645751953125
# fc2.weight gradient norm: 746.8558959960938
# fc2.bias gradient norm: 225.99412536621094
# mean.weight gradient norm: 4467.79638671875
# mean.bias gradient norm: 833.6568603515625
# ----------------------------------------------------------------------------------------------------
# Episode 1050, Reward: 44.465546446685266
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 552.0726318359375
# fc1.weight gradient norm: 133.5466766357422
# fc1.bias gradient norm: 457.5303649902344
# fc2.weight gradient norm: 351.6929016113281
# fc2.bias gradient norm: 118.1024398803711
# mean.weight gradient norm: 1115.888671875
# mean.bias gradient norm: 107.07331085205078
# ----------------------------------------------------------------------------------------------------
# Episode 1100, Reward: 79.71251797915149
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 1140.4954833984375
# fc1.weight gradient norm: 374.4356689453125
# fc1.bias gradient norm: 1722.1934814453125
# fc2.weight gradient norm: 1024.9788818359375
# fc2.bias gradient norm: 330.7396240234375
# mean.weight gradient norm: 5144.4169921875
# mean.bias gradient norm: 475.082275390625
# ----------------------------------------------------------------------------------------------------
# Episode 1150, Reward: 41.22770502417982
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 49.283973693847656
# fc1.weight gradient norm: 158.34031677246094
# fc1.bias gradient norm: 264.5832214355469
# fc2.weight gradient norm: 114.75721740722656
# fc2.bias gradient norm: 41.014644622802734
# mean.weight gradient norm: 554.7672729492188
# mean.bias gradient norm: 102.14619445800781
# ----------------------------------------------------------------------------------------------------
# Episode 1200, Reward: -99.23485942702447
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 854.3988647460938
# fc1.weight gradient norm: 569.9221801757812
# fc1.bias gradient norm: 1017.10546875
# fc2.weight gradient norm: 869.064697265625
# fc2.bias gradient norm: 188.09877014160156
# mean.weight gradient norm: 6742.21044921875
# mean.bias gradient norm: 601.8209228515625
# ----------------------------------------------------------------------------------------------------
# Episode 1250, Reward: 87.69967324236237
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 1834.530517578125
# fc1.weight gradient norm: 314.7116394042969
# fc1.bias gradient norm: 1256.6617431640625
# fc2.weight gradient norm: 694.0494995117188
# fc2.bias gradient norm: 202.368408203125
# mean.weight gradient norm: 4418.39794921875
# mean.bias gradient norm: 394.18157958984375
# ----------------------------------------------------------------------------------------------------
# Episode 1300, Reward: 77.33462370586754
# ----------------------------------------------------------------------------------------------------
# log_std gradient norm: 99.86634063720703
# fc1.weight gradient norm: 161.83053588867188
# fc1.bias gradient norm: 1624.5255126953125
# fc2.weight gradient norm: 624.4699096679688
# fc2.bias gradient norm: 252.3786163330078
# mean.weight gradient norm: 2691.50341796875
# mean.bias gradient norm: 380.5450744628906
# ----------------------------------------------------------------------------------------------------
# Episode 1350, Reward: 77.34442846262883
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Results (10 points)

# %%
# Plotting Results
window_size = 50  # Moving average window size

# Exponential Moving Average calculation
def exponential_moving_average(data, window_size):
    alpha = 2 / (window_size + 1)  # Smoothing factor
    return np.convolve(data, [alpha * (1 - alpha) ** i for i in range(window_size)], mode='valid')

plt.plot(rewards, label="REINFORCE", alpha=0.5, color='tab:green')

# Plotting exponential moving averages
plt.plot(exponential_moving_average(rewards, window_size), label="Exponential Moving Avg", linestyle='--', color='tab:green')

plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.legend()
plt.title("REINFORCE: MountainCarContinuous")
plt.show()

# %%
mean_reward, std_reward = np.mean(rewards), np.std(rewards)
print(f"mean_reward = {mean_reward:.2f} +/- {std_reward:.4f}")
# Out:
# mean_reward = -5.76 +/- 73.7588

# %% [markdown]
# **Question 3: (10 points)**
#
# What strategies can be employed to reduce catastrophic forgetting in continuous action space environments like MountainCarContinuous?
# </br>(Hint: experience replay or target networks)
#
# .....</br>
# .....</br>
#
# `Check the Report`

# %% [markdown]
# # Simulation

# %%
# Record the simulation using the optimal policy
record_simulation(gym.make("MountainCarContinuous-v0", render_mode='rgb_array', new_step_api=True), policy, "Video_MountainCarContinuous_REINFORCE")
# Out:
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>
